# %%
import torch
a = torch.load('/rds/projects/l/liuje-multiai/shuo/7788/motordock/data/qbiolip/4h4e_1_10G_D_motordock.pt')

# %%
csv_files
# Out:
# ['binding_affinity/1mhp_LC_benchmarking_data.csv',
#  'binding_affinity/1mlc_benchmarking_data.csv',
#  'binding_affinity/1n8z_benchmarking_data.csv',
#  'binding_affinity/2fjg_benchmarking_data.csv',
#  'binding_affinity/3gbn_h1_benchmarking_data.csv',
#  'binding_affinity/3gbn_h9_benchmarking_data.csv',
#  'binding_affinity/4fqi_h1_benchmarking_data.csv',
#  'binding_affinity/4fqi_h3_benchmarking_data.csv',
#  'binding_affinity/5a12_ang2_benchmarking_data.csv',
#  'binding_affinity/5a12_vegf_benchmarking_data.csv',
#  'binding_affinity/aayl49_ML_benchmarking_data.csv',
#  'binding_affinity/aayl49_benchmarking_data.csv',
#  'binding_affinity/aayl50_LC_benchmarking_data.csv',
#  'binding_affinity/aayl51_benchmarking_data.csv',
#  'binding_affinity/aayl52_LC_benchmarking_data.csv',
#  'binding_affinity/g6_LC_benchmarking_data.csv']

# %%
a['supervision']
# Out:
# {'binding_case_v2': 'unknown',
#  'true_contact_unit_indices': tensor([0, 2]),
#  'true_contact_pair_indices': tensor([1]),
#  'contact_residue_indices': tensor([ 14,  39,  40,  72,  73,  98, 166, 167, 223, 224, 225, 226, 267, 268]),
#  'ligand_contact_dist': tensor([29.2391, 27.5818, 23.9418, 22.2556, 19.1130, 16.9334, 16.5885, 14.1929,
#          11.6377,  9.4601,  8.0116,  7.3706,  9.1255,  6.5034,  5.7152,  9.3695,
#          10.1241,  8.1763, 10.2937, 13.2440, 13.0104, 13.5768, 15.9619, 17.9334,
#          18.1685, 19.5453, 21.9797, 23.1175, 23.5939, 23.7368, 22.3389, 21.3856,
#          18.5554, 17.0915, 13.3767, 12.4214, 10.0210,  7.7916,  6.9750,  3.4244,
#           3.6178,  6.2271,  9.7710, 11.6805, 10.0138, 10.1464, 13.6960, 14.7674,
#          14.1781, 15.8294, 18.7467, 19.1363, 19.3929, 16.2725, 16.5592, 13.6938,
#          15.3618, 14.9649, 17.8746, 19.0266, 22.5170, 21.5043, 21.5410, 24.8798,
# ...
